# %% [markdown]
# ###Practice Program 1
# Write a program to find the area and volume of a cube.

# %%
a = int(input('Enter the edge of the cube: '))

area = 6 * (a**2)
volume = a**3

print('Area of the cube = ', area)
print('Volume of the cube = ', volume)
# Out:
# Enter the edge of the cube: 3
# Area of the cube =  54
# Volume of the cube =  27

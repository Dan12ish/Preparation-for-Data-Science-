# %% [markdown]
# ###Practice Program 3
# Write a program to find number of sentences in a string.

# %%
string = str(input('Enter string: '))
print(len(string.split('.'))-1)
# Out:
# Enter string: Hello. Hello world. The world is beautiful.
# 3

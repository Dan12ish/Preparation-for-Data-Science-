# %% [markdown]
# ###Practice Program 4
# Convert Farhenheit to Celsius.

# %%
farhenheit = int(input ('Enter Farhenheit: '))

celcius = ((farhenheit - 32)*5)/9

print('Temperature in celcius is: ', celcius)
# Out:
# Enter Farhenheit: 32
# Temperature in celcius is:  0.0
